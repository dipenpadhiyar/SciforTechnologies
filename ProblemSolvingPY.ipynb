# %% [markdown]
# # SCIFORTECH ASSIGMENT (DATE : DEC 29 2023)

# %% [markdown]
# (1)What is the difference between list and tuple in Python?
# ```
# List: Mutable, denoted by [], allows changes.
# Tuple: Immutable, denoted by (), doesn't change after creation.
# ```
# (2)Explain the concept of PEP 8.
# ```
# Style guide for clean, readable Python code.
# ```
#
# (3)What is the purpose of the __init__ method in Python classes?
# ```
# The __init__ method is a constructor in Python classes. It's called when a new object is created, allowing you to initialize its attributes.
# ```
#
# (4)How does inheritance work in Python? Provide an example.
# ```python
# #Inheritance allows a new class (subclass) to inherit properties and behaviors (methods) from an existing class (base class).
# class car:
#   name = None
#   brand = None
#   def __init__(self,fname,fbrand):
#     global name, brand
#     name = fname
#     brand = fbrand
#     print("here")
#   def keys(self):
#     print("key value")
#
# class tata(car):
#   model = None
#   def __init__(self,fmodel):
#     global model
#     model = fmodel
#     super().__init__(model,"tata")
#     print(model)
#
# tata("TATA tiago")
#
# output :
# TATA tiago
#
#
# ```
# (5)Explain the difference between staticmethod and classmethod.
# ```
# staticmethod is a method that doesn't receive the instance or class as its first argument explicitly.
# classmethod takes the class itself as the first argument, allowing access to the class and its properties.
# ```
#
# (6)What is Polymorphism in Python? Give an example.
# ```python
# Polymorphism allows objects of different classes to be treated as objects of a common superclass.
#
# class Car:
#     def drive(self):
#         raise NotImplementedError("Subclasses must implement this method")
#
#
# class Sedan(Car):
#     def drive(self):
#         print("Sedan is cruising smoothly")
#
#
# class SUV(Car):
#     def drive(self):
#         print("SUV is handling rough terrain")
#
#
# # Polymorphic behavior
# def drive_car(car):
#     car.drive()
#
#
# sedan = Sedan()
# suv = SUV()
#
# drive_car(sedan)
# drive_car(suv)
#
# ```
#
# (7)How do you handle exceptions in Python?
# ```
# Use try, except, else, and finally blocks to handle exceptions and manage unexpected errors.
# ```
# (8)Explain the Global Interpreter Lock (GIL) in Python.
# ```
# ?
# ```
# (9)What is a decorator in Python? Provide an example.
# How do you implement encapsulation in Python?
# ```python
# A decorator is a function that modifies the behavior of another function or method.
# It takes a function as an argument and returns a new function.
# example :
# def func1(msg):    # here, we are creating a function and passing the parameter
#     print(msg)
# func1("Hii, welcome to function ")   # Here, we are printing the data of function 1
# func2 = func1      # Here, we are copying the function 1 data to function 2
# func2("Hii, welcome to function ")   # Here, we are printing the data of function 2
#
# Encapsulation is the concept of restricting access to certain parts of an object, usually by using private variables and methods.
# ```
#
# (10)Explain the concept of duck typing.
# ```
# Duck typing in Python focuses on an object’s behavior rather than its type.
#
# If an object performs certain methods or behaviors, it is considered to be of a certain type, regardless of its actual type or inheritance.
# ```
# (11)What is the difference between append() and extend() methods for lists?
# ```
# append() adds an element (single item) to the end of a list.
# extend() adds elements from an iterable (list, tuple, etc.) to the end of a list.
# ```
#
# (12)How does the with statement work in Python?
# ```python
# In Python, with statement is used in exception handling to make the code cleaner and much more readable.
#
# # using with statement
# with open('file_path', 'w') as file:
#     file.write('hello world !')
# ```
#
# (13)Discuss the use of self in Python classes.
# ```
# self refers to the instance of the class and is used to access instance variables and methods within the class.
# ```
#
# (14)Explain the purpose of the __slots__ attribute.
# ```
# __slots__ in a class allows you to explicitly define which attributes the instances of the class can have.
# It saves memory by preventing the creation of instance dictionaries.
#
# ```
#
# (15)What is the difference between an instance variable and a class variable?
# How do you implement Encapsulation, Abstraction, Polymorphism?
# ```python
# Instance Variable:
# -Belongs to an instance of a class.
# -Each instance (object) of the class has its own copy.
# -Defined inside methods and initialized using self.
# -Accessed using instance/object reference (self.variable).
#
# Class Variable:
# -Belongs to the class itself.
# -Shared among all instances of the class.
# -Defined outside methods and within the class body.
#
# from abc import ABC, abstractmethod
#
# class EncapsulationExample:
#     class Book:
#         def __init__(self, title, author):
#             self.__title = title
#             self.__author = author
#
#         def get_title(self):
#             return self.__title
#
#         def get_author(self):
#             return self.__author
#
#     class AbstractionExample(ABC):
#         @abstractmethod
#         def calculate(self):
#             pass
#
#     class Rectangle(AbstractionExample):
#         def __init__(self, length, width):
#             self.length = length
#             self.width = width
#
#         def calculate(self):
#             return self.length * self.width
#
#     class PolymorphismExample:
#         def sum(self, a, b, c=0):
#             return a + b + c
#
# example = EncapsulationExample()
#
# # Encapsulation
# book_instance = example.Book(title="Wings of Fire", author="Dr. A. P. J. Abdul Kalam")
# print(book_instance.get_title())
# print(book_instance.get_author())
#
# # Abstraction
# rectangle_instance = example.Rectangle(length=5, width=10)
# print(rectangle_instance.calculate())
#
# # Polymorphism
# polymorphism_example = example.PolymorphismExample()
# print(polymorphism_example.sum(3, 4))
# print(polymorphism_example.sum(3, 4, 9))
# ```
#
# (16)How do you Implement single level Inheritance, multiple level inheritance, multi level inheritance, Hybrid Inheritance
# ```python
# # Single Level Inheritance
# class Vehicle:
#     def start(self):
#         print("Vehicle started")
#
# class Car(Vehicle):
#     def drive(self):
#         print("Car is being driven")
#
# # Multiple Level Inheritance
# class Boat:
#     def float(self):
#         print("Boat is floating")
#
# class Ship(Boat):
#     def sail(self):
#         print("Ship is sailing")
#
# # Multi Level Inheritance
# class Airplane:
#     def fly(self):
#         print("Airplane is flying")
#
# class Jet(Airplane):
#     def turbo(self):
#         print("Jet is at turbo speed")
#
# class FighterJet(Jet):
#     def attack(self):
#         print("Fighter jet is attacking")
#
# # Hybrid Inheritance (Combination of above)
# class Hybrid(Car, Ship, FighterJet):
#     pass
#
# ```
